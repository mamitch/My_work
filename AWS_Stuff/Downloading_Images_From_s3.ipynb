# %% [markdown]
# In your command line:
#
# 1. Configure your aws account by running `aws configure`.  Note:  you will need your credentials from AWS IAM for this
# 2. Download the zip file of your data from your s3 bucket by running `aws s3 cp s3://<bucket_name>/<file_path> <destination_path>`

# %%
# !aws s3 cp s3://Beautycounter-images/beautycounter.zip .
# Out:
# fatal error: An error occurred (404) when calling the HeadObject operation: Key "beautycounter.zip" does not exist

# %% [markdown]
# Now upzip your files

# %%
# !unzip beautycounter.zip
# Out:
# Archive:  beautycounter.zip
#    creating: beautycounter/
#   inflating: beautycounter/14240743_184384185328574_563352690_n.jpg
#   inflating: beautycounter/69140371_360350958188229_4063317731911313729_n.mp4
#   inflating: beautycounter/12534403_1509265022711751_1696149858_n.jpg
#   inflating: beautycounter/42456525_1755256194585795_1591196819362271821_n.jpg
#   inflating: beautycounter/13414328_509035239285641_295811034_n.jpg
#   inflating: beautycounter/25007343_368995140205847_2028606220331384832_n.jpg
#   inflating: beautycounter/11373741_105741323108408_453477590_n.jpg
#   inflating: beautycounter/28156256_809979512524038_2090596827639316480_n.jpg
#   inflating: beautycounter/36486093_2104492389822784_3038958115203579904_n.jpg
#   inflating: beautycounter/13102526_494756680711065_72135207_n.jpg
#   inflating: beautycounter/42322474_698121660561454_5411571282616008534_n.jpg
#   inflating: beautycounter/21134765_113768239321394_2227523206829309952_n.mp4
# ...
